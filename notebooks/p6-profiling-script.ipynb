# %% [markdown]
# ## Profiler des données
# 1 - Chargez les librairies nécessaires
# 2 - Chargez les fichiers
# 3 - Récupérez toutes les informations pour chaque colonnes

# %% [markdown]
# #### 1 - Chargement des libriairies pour les traitement de DB csv

# %%
import pandas as pd

# %% [markdown]
# #### 2 - Chargement des fichiers xls pour traitement

# %%
# Charge le fichier au format voulu
df_profile = pd.read_csv("../data/2016_Building_Energy_Benchmarking.csv")

# Voir les noms des feuilles disponibles si il y en a 
print(list(df_profile.keys()))
# Out:
# ['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType', 'PropertyName', 'Address', 'City', 'State', 'ZipCode', 'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood', 'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking', 'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes', 'LargestPropertyUseType', 'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA', 'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)', 'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)', 'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)', 'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus', 'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity']

# %% [markdown]
# #### 3 - Extraire toutes les infos pour chaque colonnes

# %%
def renseigne(df,name):
    df_inv = pd.DataFrame({
        'colonne': df.columns,
        'type': df.dtypes.values,
        'longueur_max': df.apply(lambda col: col.astype(str).str.len().max()).values,
        'non_null': df.notnull().sum().values,
        'nan': df.isnull().sum().values, 
        'valeur_unique':df.nunique().values,
    })
    return df_types

# Boucle sur chaque feuille si necessaire
file = {"seattle_bench": df_profile}

for nom_feuille, df in file.items():
    display(f"\n--- Feuille : {nom_feuille} ---")
    display(renseigne(df,"seattle_bench"))
# Out:
# '\n--- Feuille : seattle_bench ---'
#                             colonne     type  longueur_max  non_null   nan  \
# 0                     OSEBuildingID    int64           5.0      3376     0
# 1                          DataYear    int64           4.0      3376     0
# 2                      BuildingType      str          20.0      3376     0
# 3               PrimaryPropertyType      str          27.0      3376     0
# 4                      PropertyName      str          72.0      3376     0
# 5                           Address      str          41.0      3376     0
# 6                              City      str           7.0      3376     0
# 7                             State      str           2.0      3376     0
# 8                           ZipCode  float64           7.0      3360    16
# 9     TaxParcelIdentificationNumber      str          25.0      3376     0
# 10              CouncilDistrictCode    int64           1.0      3376     0
# 11                     Neighborhood      str          22.0      3376     0
# 12                         Latitude  float64          11.0      3376     0
# 13                        Longitude  float64          12.0      3376     0
# 14                        YearBuilt    int64           4.0      3376     0
# 15                NumberofBuildings  float64           5.0      3368     8
# 16                   NumberofFloors    int64           2.0      3376     0
# 17                 PropertyGFATotal    int64           7.0      3376     0
# 18               PropertyGFAParking    int64           6.0      3376     0
# 19           PropertyGFABuilding(s)    int64           7.0      3376     0
# 20        ListOfAllPropertyUseTypes      str         255.0      3367     9
# 21           LargestPropertyUseType      str          52.0      3356    20
# 22        LargestPropertyUseTypeGFA  float64           9.0      3356    20
# 23     SecondLargestPropertyUseType      str          52.0      1679  1697
# 24  SecondLargestPropertyUseTypeGFA  float64          11.0      1679  1697
# 25      ThirdLargestPropertyUseType      str          52.0       596  2780
# 26   ThirdLargestPropertyUseTypeGFA  float64          11.0       596  2780
# 27         YearsENERGYSTARCertified   object          60.0       119  3257
# 28                  ENERGYSTARScore  float64           5.0      2533   843
# 29                 SiteEUI(kBtu/sf)  float64          11.0      3369     7
# 30               SiteEUIWN(kBtu/sf)  float64          11.0      3370     6
# 31               SourceEUI(kBtu/sf)  float64          11.0      3367     9
# 32             SourceEUIWN(kBtu/sf)  float64          12.0      3367     9
# 33              SiteEnergyUse(kBtu)  float64          11.0      3371     5
# 34            SiteEnergyUseWN(kBtu)  float64          11.0      3370     6
# 35                   SteamUse(kBtu)  float64          11.0      3367     9
# 36                 Electricity(kWh)  float64          12.0      3367     9
# 37                Electricity(kBtu)  float64          11.0      3367     9
# 38               NaturalGas(therms)  float64          11.0      3367     9
# 39                 NaturalGas(kBtu)  float64          11.0      3367     9
# 40                      DefaultData     bool           5.0      3376     0
# 41                         Comments  float64           NaN         0  3376
# 42                 ComplianceStatus      str          28.0      3376     0
# 43                          Outlier      str          12.0        32  3344
# 44                TotalGHGEmissions  float64           8.0      3367     9
# 45            GHGEmissionsIntensity  float64           5.0      3367     9
#
#     valeur_unique
# 0            3376
# 1               1
# 2               8
# 3              24
# 4            3362
# 5            3354
# 6               1
# 7               1
# 8              55
# 9            3268
# 10              7
# 11             19
# 12           2876
# 13           2656
# 14            113
# 15             17
# 16             50
# 17           3195
# 18            496
# 19           3193
# 20            466
# 21             56
# 22           3122
# 23             50
# 24           1352
# 25             44
# 26            501
# 27             65
# 28            100
# 29           1085
# 30           1105
# 31           1648
# 32           1694
# 33           3354
# 34           3341
# 35            131
# 36           3352
# 37           3351
# 38           2109
# 39           2109
# 40              2
# 41              0
# 42              4
# 43              2
# 44           2818
# 45            511

# %%
display(df_profile.head(3))
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
#
#               PropertyName          Address     City State  ZipCode  \
# 0     Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1          Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2  5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# 1                    0659000220  ...      9.504252e+05         3242851.0
# 2                    0659000475  ...      1.451544e+07        49526664.0
#
#    NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  Comments  \
# 0         12764.52930         1276453.0        False       NaN
# 1         51450.81641         5145082.0        False       NaN
# 2         14938.00000         1493800.0        False       NaN
#
#    ComplianceStatus  Outlier  TotalGHGEmissions  GHGEmissionsIntensity
# 0         Compliant      NaN             249.98                   2.83
# 1         Compliant      NaN             295.86                   2.86
# 2         Compliant      NaN            2089.28                   2.19
#
# [3 rows x 46 columns]
